# %%
 from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/Validation/F/167.jpg
#   inflating: dataset/Validation/F/168.jpg
#   inflating: dataset/Validation/F/169.jpg
#   inflating: dataset/Validation/F/17.jpg
#   inflating: dataset/Validation/F/170.jpg
#   inflating: dataset/Validation/F/171.jpg
#   inflating: dataset/Validation/F/172.jpg
#   inflating: dataset/Validation/F/173.jpg
#   inflating: dataset/Validation/F/174.jpg
#   inflating: dataset/Validation/F/175.jpg
#   inflating: dataset/Validation/F/176.jpg
#   inflating: dataset/Validation/F/177.jpg
#   inflating: dataset/Validation/F/178.jpg
#   inflating: dataset/Validation/F/179.jpg
#   inflating: dataset/Validation/F/18.jpg
#   inflating: dataset/Validation/F/180.jpg
#   inflating: dataset/Validation/F/181.jpg
#   inflating: dataset/Validation/F/182.jpg
#   inflating: dataset/Validation/F/183.jpg
#   inflating: dataset/Validation/F/184.jpg
#   inflating: dataset/Validation/F/185.jpg
#   inflating: dataset/Validation/F/186.jpg
#   inflating: dataset/Validation/F/187.jpg
#   inflating: dataset/Validation/F/188.jpg
#   inflating: dataset/Validation/F/189.jpg
#   inflating: dataset/Validation/F/19.jpg
#   inflating: dataset/Validation/F/190.jpg
#   inflating: dataset/Validation/F/191.jpg
#   inflating: dataset/Validation/F/192.jpg
#   inflating: dataset/Validation/F/193.jpg
#   inflating: dataset/Validation/F/194.jpg
#   inflating: dataset/Validation/F/195.jpg
#   inflating: dataset/Validation/F/2.jpg
#   inflating: dataset/Validation/F/20.jpg
#   inflating: dataset/Validation/F/21.jpg
#   inflating: dataset/Validation/F/22.jpg
#   inflating: dataset/Validation/F/23.jpg
#   inflating: dataset/Validation/F/24.jpg
#   inflating: dataset/Validation/F/25.jpg
#   inflating: dataset/Validation/F/26.jpg
#   inflating: dataset/Validation/F/27.jpg
#   inflating: dataset/Validation/F/28.jpg
#   inflating: dataset/Validation/F/29.jpg
#   inflating: dataset/Validation/F/3.jpg
#   inflating: dataset/Validation/F/30.jpg
#   inflating: dataset/Validation/F/31.jpg
#   inflating: dataset/Validation/F/32.jpg
#   inflating: dataset/Validation/F/33.jpg
#   inflating: dataset/Validation/F/34.jpg
#   inflating: dataset/Validation/F/35.jpg
#   inflating: dataset/Validation/F/36.jpg
#   inflating: dataset/Validation/F/37.jpg
#   inflating: dataset/Validation/F/38.jpg
#   inflating: dataset/Validation/F/39.jpg
#   inflating: dataset/Validation/F/4.jpg
#   inflating: dataset/Validation/F/40.jpg
#   inflating: dataset/Validation/F/41.jpg
#   inflating: dataset/Validation/F/42.jpg
#   inflating: dataset/Validation/F/43.jpg
#   inflating: dataset/Validation/F/44.jpg
#   inflating: dataset/Validation/F/45.jpg
#   inflating: dataset/Validation/F/46.jpg
#   inflating: dataset/Validation/F/47.jpg
#   inflating: dataset/Validation/F/48.jpg
#   inflating: dataset/Validation/F/49.jpg
#   inflating: dataset/Validation/F/5.jpg
#   inflating: dataset/Validation/F/50.jpg
#   inflating: dataset/Validation/F/51.jpg
#   inflating: dataset/Validation/F/52.jpg
#   inflating: dataset/Validation/F/53.jpg
#   inflating: dataset/Validation/F/54.jpg
#   inflating: dataset/Validation/F/55.jpg
#   inflating: dataset/Validation/F/56.jpg
#   inflating: dataset/Validation/F/57.jpg
#   inflating: dataset/Validation/F/58.jpg
#   inflating: dataset/Validation/F/59.jpg
#   inflating: dataset/Validation/F/6.jpg
#   inflating: dataset/Validation/F/60.jpg
#   inflating: dataset/Validation/F/61.jpg
#   inflating: dataset/Validation/F/62.jpg
#   inflating: dataset/Validation/F/63.jpg
#   inflating: dataset/Validation/F/64.jpg
#   inflating: dataset/Validation/F/65.jpg
#   inflating: dataset/Validation/F/66.jpg
#   inflating: dataset/Validation/F/67.jpg
#   inflating: dataset/Validation/F/68.jpg
#   inflating: dataset/Validation/F/69.jpg
#   inflating: dataset/Validation/F/7.jpg
#   inflating: dataset/Validation/F/70.jpg
#   inflating: dataset/Validation/F/71.jpg
#   inflating: dataset/Validation/F/72.jpg
#   inflating: dataset/Validation/F/73.jpg
#   inflating: dataset/Validation/F/74.jpg
#   inflating: dataset/Validation/F/75.jpg
#   inflating: dataset/Validation/F/76.jpg
#   inflating: dataset/Validation/F/77.jpg
#   inflating: dataset/Validation/F/78.jpg
#   inflating: dataset/Validation/F/79.jpg
#   inflating: dataset/Validation/F/8.jpg
#   inflating: dataset/Validation/F/80.jpg
#   inflating: dataset/Validation/F/81.jpg
#   inflating: dataset/Validation/F/82.jpg
#   inflating: dataset/Validation/F/83.jpg
#   inflating: dataset/Validation/F/84.jpg
#   inflating: dataset/Validation/F/85.jpg
#   inflating: dataset/Validation/F/86.jpg
#   inflating: dataset/Validation/F/87.jpg
#   inflating: dataset/Validation/F/88.jpg
#   inflating: dataset/Validation/F/89.jpg
#   inflating: dataset/Validation/F/9.jpg
#   inflating: dataset/Validation/F/90.jpg
#   inflating: dataset/Validation/F/91.jpg
#   inflating: dataset/Validation/F/92.jpg
#   inflating: dataset/Validation/F/93.jpg
#   inflating: dataset/Validation/F/94.jpg
#   inflating: dataset/Validation/F/95.jpg
#   inflating: dataset/Validation/F/96.jpg
#   inflating: dataset/Validation/F/97.jpg
#   inflating: dataset/Validation/F/98.jpg
#   inflating: dataset/Validation/F/99.jpg
#   inflating: dataset/Validation/F/_1_0.jpg
#   inflating: dataset/Validation/F/_1_1.jpg
#   inflating: dataset/Validation/F/_1_100.jpg
#   inflating: dataset/Validation/F/_1_101.jpg
#   inflating: dataset/Validation/F/_1_102.jpg
#   inflating: dataset/Validation/F/_1_104.jpg
#   inflating: dataset/Validation/F/_1_105.jpg
#   inflating: dataset/Validation/F/_1_106.jpg
#   inflating: dataset/Validation/F/_1_107.jpg
#   inflating: dataset/Validation/F/_1_108.jpg
#   inflating: dataset/Validation/F/_1_109.jpg
#   inflating: dataset/Validation/F/_1_11.jpg
#   inflating: dataset/Validation/F/_1_110.jpg
#   inflating: dataset/Validation/F/_1_111.jpg
#   inflating: dataset/Validation/F/_1_112.jpg
#   inflating: dataset/Validation/F/_1_113.jpg
#   inflating: dataset/Validation/F/_1_114.jpg
#   inflating: dataset/Validation/F/_1_115.jpg
#   inflating: dataset/Validation/F/_1_117.jpg
#   inflating: dataset/Validation/F/_1_118.jpg
#   inflating: dataset/Validation/F/_1_119.jpg
#   inflating: dataset/Validation/F/_1_12.jpg
#   inflating: dataset/Validation/F/_1_120.jpg
#   inflating: dataset/Validation/F/_1_121.jpg
#   inflating: dataset/Validation/F/_1_122.jpg
#   inflating: dataset/Validation/F/_1_123.jpg
#   inflating: dataset/Validation/F/_1_124.jpg
#   inflating: dataset/Validation/F/_1_125.jpg
#   inflating: dataset/Validation/F/_1_126.jpg
#   inflating: dataset/Validation/F/_1_127.jpg
#   inflating: dataset/Validation/F/_1_128.jpg
#   inflating: dataset/Validation/F/_1_129.jpg
#   inflating: dataset/Validation/F/_1_13.jpg
#   inflating: dataset/Validation/F/_1_130.jpg
#   inflating: dataset/Validation/F/_1_131.jpg
#   inflating: dataset/Validation/F/_1_132.jpg
#   inflating: dataset/Validation/F/_1_133.jpg
#   inflating: dataset/Validation/F/_1_134.jpg
#   inflating: dataset/Validation/F/_1_135.jpg
#   inflating: dataset/Validation/F/_1_136.jpg
#   inflating: dataset/Validation/F/_1_138.jpg
#   inflating: dataset/Validation/F/_1_139.jpg
#   inflating: dataset/Validation/F/_1_14.jpg
#   inflating: dataset/Validation/F/_1_140.jpg
#   inflating: dataset/Validation/F/_1_141.jpg
#   inflating: dataset/Validation/F/_1_142.jpg
#   inflating: dataset/Validation/F/_1_144.jpg
#   inflating: dataset/Validation/F/_1_145.jpg
#   inflating: dataset/Validation/F/_1_146.jpg
#   inflating: dataset/Validation/F/_1_15.jpg
#   inflating: dataset/Validation/F/_1_17.jpg
#   inflating: dataset/Validation/F/_1_18.jpg
#   inflating: dataset/Validation/F/_1_2.jpg
#   inflating: dataset/Validation/F/_1_20.jpg
#   inflating: dataset/Validation/F/_1_21.jpg
#   inflating: dataset/Validation/F/_1_22.jpg
#   inflating: dataset/Validation/F/_1_23.jpg
#   inflating: dataset/Validation/F/_1_24.jpg
#   inflating: dataset/Validation/F/_1_25.jpg
#   inflating: dataset/Validation/F/_1_26.jpg
#   inflating: dataset/Validation/F/_1_27.jpg
#   inflating: dataset/Validation/F/_1_28.jpg
#   inflating: dataset/Validation/F/_1_29.jpg
#   inflating: dataset/Validation/F/_1_30.jpg
#   inflating: dataset/Validation/F/_1_31.jpg
#   inflating: dataset/Validation/F/_1_32.jpg
#   inflating: dataset/Validation/F/_1_33.jpg
#   inflating: dataset/Validation/F/_1_34.jpg
#   inflating: dataset/Validation/F/_1_35.jpg
#   inflating: dataset/Validation/F/_1_36.jpg
#   inflating: dataset/Validation/F/_1_37.jpg
#   inflating: dataset/Validation/F/_1_38.jpg
#   inflating: dataset/Validation/F/_1_39.jpg
#   inflating: dataset/Validation/F/_1_4.jpg
#   inflating: dataset/Validation/F/_1_40.jpg
#   inflating: dataset/Validation/F/_1_41.jpg
#   inflating: dataset/Validation/F/_1_42.jpg
#   inflating: dataset/Validation/F/_1_43.jpg
#   inflating: dataset/Validation/F/_1_44.jpg
#   inflating: dataset/Validation/F/_1_45.jpg
#   inflating: dataset/Validation/F/_1_46.jpg
#   inflating: dataset/Validation/F/_1_47.jpg
#   inflating: dataset/Validation/F/_1_49.jpg
#   inflating: dataset/Validation/F/_1_5.jpg
#   inflating: dataset/Validation/F/_1_51.jpg
#   inflating: dataset/Validation/F/_1_52.jpg
#   inflating: dataset/Validation/F/_1_53.jpg
#   inflating: dataset/Validation/F/_1_55.jpg
#   inflating: dataset/Validation/F/_1_56.jpg
#   inflating: dataset/Validation/F/_1_57.jpg
#   inflating: dataset/Validation/F/_1_58.jpg
#   inflating: dataset/Validation/F/_1_59.jpg
#   inflating: dataset/Validation/F/_1_60.jpg
#   inflating: dataset/Validation/F/_1_61.jpg
#   inflating: dataset/Validation/F/_1_62.jpg
#   inflating: dataset/Validation/F/_1_63.jpg
#   inflating: dataset/Validation/F/_1_64.jpg
#   inflating: dataset/Validation/F/_1_67.jpg
#   inflating: dataset/Validation/F/_1_68.jpg
#   inflating: dataset/Validation/F/_1_69.jpg
#   inflating: dataset/Validation/F/_1_70.jpg
#   inflating: dataset/Validation/F/_1_71.jpg
#   inflating: dataset/Validation/F/_1_73.jpg
#   inflating: dataset/Validation/F/_1_74.jpg
#   inflating: dataset/Validation/F/_1_75.jpg
#   inflating: dataset/Validation/F/_1_76.jpg
#   inflating: dataset/Validation/F/_1_77.jpg
#   inflating: dataset/Validation/F/_1_78.jpg
#   inflating: dataset/Validation/F/_1_79.jpg
#   inflating: dataset/Validation/F/_1_80.jpg
#   inflating: dataset/Validation/F/_1_81.jpg
#   inflating: dataset/Validation/F/_1_82.jpg
#   inflating: dataset/Validation/F/_1_83.jpg
#   inflating: dataset/Validation/F/_1_84.jpg
#   inflating: dataset/Validation/F/_1_86.jpg
#   inflating: dataset/Validation/F/_1_87.jpg
#   inflating: dataset/Validation/F/_1_88.jpg
#   inflating: dataset/Validation/F/_1_89.jpg
#   inflating: dataset/Validation/F/_1_9.jpg
#   inflating: dataset/Validation/F/_1_90.jpg
#   inflating: dataset/Validation/F/_1_91.jpg
#   inflating: dataset/Validation/F/_1_92.jpg
#   inflating: dataset/Validation/F/_1_93.jpg
#   inflating: dataset/Validation/F/_1_94.jpg
#   inflating: dataset/Validation/F/_1_96.jpg
#   inflating: dataset/Validation/F/_1_97.jpg
#   inflating: dataset/Validation/F/_1_98.jpg
#   inflating: dataset/Validation/F/_1_99.jpg
#   inflating: dataset/Validation/G/0.jpg
#   inflating: dataset/Validation/G/1.jpg
#   inflating: dataset/Validation/G/10.jpg
#   inflating: dataset/Validation/G/100.jpg
#   inflating: dataset/Validation/G/101.jpg
#   inflating: dataset/Validation/G/104.jpg
#   inflating: dataset/Validation/G/106.jpg
#   inflating: dataset/Validation/G/107.jpg
#   inflating: dataset/Validation/G/109.jpg
#   inflating: dataset/Validation/G/11.jpg
#   inflating: dataset/Validation/G/110.jpg
#   inflating: dataset/Validation/G/111.jpg
#   inflating: dataset/Validation/G/112.jpg
#   inflating: dataset/Validation/G/113.jpg
#   inflating: dataset/Validation/G/114.jpg
#   inflating: dataset/Validation/G/115.jpg
#   inflating: dataset/Validation/G/116.jpg
#   inflating: dataset/Validation/G/119.jpg
#   inflating: dataset/Validation/G/12.jpg
#   inflating: dataset/Validation/G/120.jpg
#   inflating: dataset/Validation/G/121.jpg
#   inflating: dataset/Validation/G/122.jpg
#   inflating: dataset/Validation/G/123.jpg
#   inflating: dataset/Validation/G/124.jpg
#   inflating: dataset/Validation/G/125.jpg
#   inflating: dataset/Validation/G/126.jpg
#   inflating: dataset/Validation/G/127.jpg
#   inflating: dataset/Validation/G/128.jpg
#   inflating: dataset/Validation/G/129.jpg
#   inflating: dataset/Validation/G/13.jpg
#   inflating: dataset/Validation/G/130.jpg
#   inflating: dataset/Validation/G/131.jpg
#   inflating: dataset/Validation/G/132.jpg
#   inflating: dataset/Validation/G/133.jpg
#   inflating: dataset/Validation/G/134.jpg
#   inflating: dataset/Validation/G/135.jpg
#   inflating: dataset/Validation/G/136.jpg
#   inflating: dataset/Validation/G/137.jpg
#   inflating: dataset/Validation/G/138.jpg
#   inflating: dataset/Validation/G/139.jpg
#   inflating: dataset/Validation/G/14.jpg
#   inflating: dataset/Validation/G/140.jpg
#   inflating: dataset/Validation/G/141.jpg
#   inflating: dataset/Validation/G/142.jpg
#   inflating: dataset/Validation/G/143.jpg
#   inflating: dataset/Validation/G/144.jpg
#   inflating: dataset/Validation/G/145.jpg
#   inflating: dataset/Validation/G/146.jpg
#   inflating: dataset/Validation/G/147.jpg
#   inflating: dataset/Validation/G/148.jpg
#   inflating: dataset/Validation/G/149.jpg
#   inflating: dataset/Validation/G/15.jpg
#   inflating: dataset/Validation/G/150.jpg
#   inflating: dataset/Validation/G/151.jpg
#   inflating: dataset/Validation/G/152.jpg
#   inflating: dataset/Validation/G/153.jpg
#   inflating: dataset/Validation/G/154.jpg
#   inflating: dataset/Validation/G/155.jpg
#   inflating: dataset/Validation/G/156.jpg
#   inflating: dataset/Validation/G/157.jpg
#   inflating: dataset/Validation/G/158.jpg
#   inflating: dataset/Validation/G/159.jpg
#   inflating: dataset/Validation/G/16.jpg
#   inflating: dataset/Validation/G/160.jpg
#   inflating: dataset/Validation/G/162.jpg
#   inflating: dataset/Validation/G/165.jpg
#   inflating: dataset/Validation/G/166.jpg
#   inflating: dataset/Validation/G/167.jpg
#   inflating: dataset/Validation/G/168.jpg
#   inflating: dataset/Validation/G/169.jpg
#   inflating: dataset/Validation/G/17.jpg
#   inflating: dataset/Validation/G/171.jpg
#   inflating: dataset/Validation/G/172.jpg
#   inflating: dataset/Validation/G/173.jpg
#   inflating: dataset/Validation/G/174.jpg
#   inflating: dataset/Validation/G/175.jpg
#   inflating: dataset/Validation/G/176.jpg
#   inflating: dataset/Validation/G/177.jpg
#   inflating: dataset/Validation/G/178.jpg
#   inflating: dataset/Validation/G/179.jpg
#   inflating: dataset/Validation/G/180.jpg
#   inflating: dataset/Validation/G/181.jpg
#   inflating: dataset/Validation/G/19.jpg
#   inflating: dataset/Validation/G/2.jpg
#   inflating: dataset/Validation/G/20.jpg
#   inflating: dataset/Validation/G/21.jpg
#   inflating: dataset/Validation/G/22.jpg
#   inflating: dataset/Validation/G/23.jpg
#   inflating: dataset/Validation/G/24.jpg
#   inflating: dataset/Validation/G/26.jpg
#   inflating: dataset/Validation/G/29.jpg
#   inflating: dataset/Validation/G/3.jpg
#   inflating: dataset/Validation/G/31.jpg
#   inflating: dataset/Validation/G/32.jpg
#   inflating: dataset/Validation/G/33.jpg
#   inflating: dataset/Validation/G/34.jpg
#   inflating: dataset/Validation/G/35.jpg
#   inflating: dataset/Validation/G/36.jpg
#   inflating: dataset/Validation/G/37.jpg
#   inflating: dataset/Validation/G/38.jpg
#   inflating: dataset/Validation/G/4.jpg
#   inflating: dataset/Validation/G/40.jpg
#   inflating: dataset/Validation/G/41.jpg
#   inflating: dataset/Validation/G/42.jpg
#   inflating: dataset/Validation/G/43.jpg
#   inflating: dataset/Validation/G/44.jpg
#   inflating: dataset/Validation/G/45.jpg
#   inflating: dataset/Validation/G/46.jpg
#   inflating: dataset/Validation/G/48.jpg
#   inflating: dataset/Validation/G/5.jpg
#   inflating: dataset/Validation/G/50.jpg
#   inflating: dataset/Validation/G/51.jpg
#   inflating: dataset/Validation/G/52.jpg
#   inflating: dataset/Validation/G/53.jpg
#   inflating: dataset/Validation/G/54.jpg
#   inflating: dataset/Validation/G/56.jpg
#   inflating: dataset/Validation/G/57.jpg
#   inflating: dataset/Validation/G/58.jpg
#   inflating: dataset/Validation/G/59.jpg
#   inflating: dataset/Validation/G/6.jpg
#   inflating: dataset/Validation/G/61.jpg
#   inflating: dataset/Validation/G/62.jpg
#   inflating: dataset/Validation/G/63.jpg
#   inflating: dataset/Validation/G/64.jpg
#   inflating: dataset/Validation/G/65.jpg
#   inflating: dataset/Validation/G/66.jpg
#   inflating: dataset/Validation/G/67.jpg
#   inflating: dataset/Validation/G/68.jpg
#   inflating: dataset/Validation/G/69.jpg
#   inflating: dataset/Validation/G/7.jpg
#   inflating: dataset/Validation/G/70.jpg
#   inflating: dataset/Validation/G/71.jpg
#   inflating: dataset/Validation/G/72.jpg
#   inflating: dataset/Validation/G/74.jpg
#   inflating: dataset/Validation/G/75.jpg
#   inflating: dataset/Validation/G/76.jpg
#   inflating: dataset/Validation/G/77.jpg
#   inflating: dataset/Validation/G/78.jpg
#   inflating: dataset/Validation/G/79.jpg
#   inflating: dataset/Validation/G/8.jpg
#   inflating: dataset/Validation/G/80.jpg
#   inflating: dataset/Validation/G/81.jpg
#   inflating: dataset/Validation/G/82.jpg
#   inflating: dataset/Validation/G/83.jpg
#   inflating: dataset/Validation/G/84.jpg
#   inflating: dataset/Validation/G/85.jpg
#   inflating: dataset/Validation/G/86.jpg
#   inflating: dataset/Validation/G/87.jpg
#   inflating: dataset/Validation/G/88.jpg
#   inflating: dataset/Validation/G/9.jpg
#   inflating: dataset/Validation/G/90.jpg
#   inflating: dataset/Validation/G/91.jpg
#   inflating: dataset/Validation/G/92.jpg
#   inflating: dataset/Validation/G/93.jpg
#   inflating: dataset/Validation/G/94.jpg
#   inflating: dataset/Validation/G/95.jpg
#   inflating: dataset/Validation/G/96.jpg
#   inflating: dataset/Validation/G/97.jpg
#   inflating: dataset/Validation/G/98.jpg
#   inflating: dataset/Validation/G/99.jpg
#   inflating: dataset/Validation/G/_1_0.jpg
#   inflating: dataset/Validation/G/_1_1.jpg
#   inflating: dataset/Validation/G/_1_10.jpg
#   inflating: dataset/Validation/G/_1_100.jpg
#   inflating: dataset/Validation/G/_1_101.jpg
#   inflating: dataset/Validation/G/_1_102.jpg
#   inflating: dataset/Validation/G/_1_103.jpg
#   inflating: dataset/Validation/G/_1_104.jpg
#   inflating: dataset/Validation/G/_1_105.jpg
#   inflating: dataset/Validation/G/_1_106.jpg
#   inflating: dataset/Validation/G/_1_107.jpg
#   inflating: dataset/Validation/G/_1_108.jpg
#   inflating: dataset/Validation/G/_1_109.jpg
#   inflating: dataset/Validation/G/_1_11.jpg
#   inflating: dataset/Validation/G/_1_110.jpg
#   inflating: dataset/Validation/G/_1_111.jpg
#   inflating: dataset/Validation/G/_1_112.jpg
#   inflating: dataset/Validation/G/_1_113.jpg
#   inflating: dataset/Validation/G/_1_114.jpg
#   inflating: dataset/Validation/G/_1_115.jpg
#   inflating: dataset/Validation/G/_1_116.jpg
#   inflating: dataset/Validation/G/_1_117.jpg
#   inflating: dataset/Validation/G/_1_118.jpg
#   inflating: dataset/Validation/G/_1_119.jpg
#   inflating: dataset/Validation/G/_1_12.jpg
#   inflating: dataset/Validation/G/_1_120.jpg
#   inflating: dataset/Validation/G/_1_121.jpg
#   inflating: dataset/Validation/G/_1_122.jpg
#   inflating: dataset/Validation/G/_1_123.jpg
#   inflating: dataset/Validation/G/_1_124.jpg
#   inflating: dataset/Validation/G/_1_125.jpg
#   inflating: dataset/Validation/G/_1_126.jpg
#   inflating: dataset/Validation/G/_1_127.jpg
#   inflating: dataset/Validation/G/_1_128.jpg
#   inflating: dataset/Validation/G/_1_129.jpg
#   inflating: dataset/Validation/G/_1_13.jpg
#   inflating: dataset/Validation/G/_1_130.jpg
#   inflating: dataset/Validation/G/_1_131.jpg
#   inflating: dataset/Validation/G/_1_132.jpg
#   inflating: dataset/Validation/G/_1_133.jpg
#   inflating: dataset/Validation/G/_1_134.jpg
#   inflating: dataset/Validation/G/_1_135.jpg
#   inflating: dataset/Validation/G/_1_136.jpg
#   inflating: dataset/Validation/G/_1_137.jpg
#   inflating: dataset/Validation/G/_1_138.jpg
#   inflating: dataset/Validation/G/_1_139.jpg
#   inflating: dataset/Validation/G/_1_14.jpg
#   inflating: dataset/Validation/G/_1_140.jpg
#   inflating: dataset/Validation/G/_1_141.jpg
#   inflating: dataset/Validation/G/_1_142.jpg
#   inflating: dataset/Validation/G/_1_143.jpg
#   inflating: dataset/Validation/G/_1_144.jpg
#   inflating: dataset/Validation/G/_1_145.jpg
#   inflating: dataset/Validation/G/_1_146.jpg
#   inflating: dataset/Validation/G/_1_147.jpg
#   inflating: dataset/Validation/G/_1_148.jpg
#   inflating: dataset/Validation/G/_1_149.jpg
#   inflating: dataset/Validation/G/_1_15.jpg
#   inflating: dataset/Validation/G/_1_150.jpg
#   inflating: dataset/Validation/G/_1_151.jpg
#   inflating: dataset/Validation/G/_1_152.jpg
#   inflating: dataset/Validation/G/_1_153.jpg
#   inflating: dataset/Validation/G/_1_154.jpg
#   inflating: dataset/Validation/G/_1_155.jpg
#   inflating: dataset/Validation/G/_1_156.jpg
#   inflating: dataset/Validation/G/_1_157.jpg
#   inflating: dataset/Validation/G/_1_158.jpg
#   inflating: dataset/Validation/G/_1_159.jpg
#   inflating: dataset/Validation/G/_1_16.jpg
#   inflating: dataset/Validation/G/_1_160.jpg
#   inflating: dataset/Validation/G/_1_161.jpg
#   inflating: dataset/Validation/G/_1_162.jpg
#   inflating: dataset/Validation/G/_1_163.jpg
#   inflating: dataset/Validation/G/_1_164.jpg
#   inflating: dataset/Validation/G/_1_165.jpg
#   inflating: dataset/Validation/G/_1_166.jpg
#   inflating: dataset/Validation/G/_1_167.jpg
#   inflating: dataset/Validation/G/_1_168.jpg
#   inflating: dataset/Validation/G/_1_169.jpg
#   inflating: dataset/Validation/G/_1_17.jpg
#   inflating: dataset/Validation/G/_1_170.jpg
#   inflating: dataset/Validation/G/_1_171.jpg
#   inflating: dataset/Validation/G/_1_172.jpg
#   inflating: dataset/Validation/G/_1_173.jpg
#   inflating: dataset/Validation/G/_1_174.jpg
#   inflating: dataset/Validation/G/_1_175.jpg
#   inflating: dataset/Validation/G/_1_176.jpg
#   inflating: dataset/Validation/G/_1_177.jpg
#   inflating: dataset/Validation/G/_1_178.jpg
#   inflating: dataset/Validation/G/_1_179.jpg
#   inflating: dataset/Validation/G/_1_18.jpg
#   inflating: dataset/Validation/G/_1_180.jpg
#   inflating: dataset/Validation/G/_1_181.jpg
#   inflating: dataset/Validation/G/_1_182.jpg
#   inflating: dataset/Validation/G/_1_183.jpg
#   inflating: dataset/Validation/G/_1_184.jpg
#   inflating: dataset/Validation/G/_1_185.jpg
#   inflating: dataset/Validation/G/_1_186.jpg
#   inflating: dataset/Validation/G/_1_187.jpg
#   inflating: dataset/Validation/G/_1_188.jpg
#   inflating: dataset/Validation/G/_1_189.jpg
#   inflating: dataset/Validation/G/_1_19.jpg
#   inflating: dataset/Validation/G/_1_190.jpg
#   inflating: dataset/Validation/G/_1_191.jpg
#   inflating: dataset/Validation/G/_1_192.jpg
#   inflating: dataset/Validation/G/_1_193.jpg
#   inflating: dataset/Validation/G/_1_194.jpg
#   inflating: dataset/Validation/G/_1_195.jpg
#   inflating: dataset/Validation/G/_1_196.jpg
#   inflating: dataset/Validation/G/_1_197.jpg
#   inflating: dataset/Validation/G/_1_198.jpg
#   inflating: dataset/Validation/G/_1_199.jpg
#   inflating: dataset/Validation/G/_1_2.jpg
#   inflating: dataset/Validation/G/_1_20.jpg
#   inflating: dataset/Validation/G/_1_200.jpg
#   inflating: dataset/Validation/G/_1_201.jpg
#   inflating: dataset/Validation/G/_1_202.jpg
#   inflating: dataset/Validation/G/_1_21.jpg
#   inflating: dataset/Validation/G/_1_22.jpg
#   inflating: dataset/Validation/G/_1_23.jpg
#   inflating: dataset/Validation/G/_1_24.jpg
#   inflating: dataset/Validation/G/_1_25.jpg
#   inflating: dataset/Validation/G/_1_26.jpg
#   inflating: dataset/Validation/G/_1_27.jpg
#   inflating: dataset/Validation/G/_1_28.jpg
#   inflating: dataset/Validation/G/_1_29.jpg
#   inflating: dataset/Validation/G/_1_3.jpg
#   inflating: dataset/Validation/G/_1_30.jpg
#   inflating: dataset/Validation/G/_1_31.jpg
#   inflating: dataset/Validation/G/_1_32.jpg
#   inflating: dataset/Validation/G/_1_33.jpg
#   inflating: dataset/Validation/G/_1_34.jpg
#   inflating: dataset/Validation/G/_1_35.jpg
#   inflating: dataset/Validation/G/_1_36.jpg
#   inflating: dataset/Validation/G/_1_37.jpg
#   inflating: dataset/Validation/G/_1_38.jpg
#   inflating: dataset/Validation/G/_1_39.jpg
#   inflating: dataset/Validation/G/_1_4.jpg
#   inflating: dataset/Validation/G/_1_40.jpg
#   inflating: dataset/Validation/G/_1_41.jpg
#   inflating: dataset/Validation/G/_1_42.jpg
#   inflating: dataset/Validation/G/_1_43.jpg
#   inflating: dataset/Validation/G/_1_44.jpg
#   inflating: dataset/Validation/G/_1_45.jpg
#   inflating: dataset/Validation/G/_1_46.jpg
#   inflating: dataset/Validation/G/_1_47.jpg
#   inflating: dataset/Validation/G/_1_48.jpg
#   inflating: dataset/Validation/G/_1_49.jpg
#   inflating: dataset/Validation/G/_1_5.jpg
#   inflating: dataset/Validation/G/_1_50.jpg
#   inflating: dataset/Validation/G/_1_51.jpg
#   inflating: dataset/Validation/G/_1_52.jpg
#   inflating: dataset/Validation/G/_1_53.jpg
#   inflating: dataset/Validation/G/_1_54.jpg
#   inflating: dataset/Validation/G/_1_55.jpg
#   inflating: dataset/Validation/G/_1_56.jpg
#   inflating: dataset/Validation/G/_1_57.jpg
#   inflating: dataset/Validation/G/_1_58.jpg
#   inflating: dataset/Validation/G/_1_59.jpg
#   inflating: dataset/Validation/G/_1_6.jpg
#   inflating: dataset/Validation/G/_1_60.jpg
#   inflating: dataset/Validation/G/_1_61.jpg
#   inflating: dataset/Validation/G/_1_62.jpg
#   inflating: dataset/Validation/G/_1_63.jpg
#   inflating: dataset/Validation/G/_1_64.jpg
#   inflating: dataset/Validation/G/_1_65.jpg
#   inflating: dataset/Validation/G/_1_66.jpg
#   inflating: dataset/Validation/G/_1_67.jpg
#   inflating: dataset/Validation/G/_1_68.jpg
#   inflating: dataset/Validation/G/_1_69.jpg
#   inflating: dataset/Validation/G/_1_7.jpg
#   inflating: dataset/Validation/G/_1_70.jpg
#   inflating: dataset/Validation/G/_1_71.jpg
#   inflating: dataset/Validation/G/_1_72.jpg
#   inflating: dataset/Validation/G/_1_73.jpg
#   inflating: dataset/Validation/G/_1_74.jpg
#   inflating: dataset/Validation/G/_1_75.jpg
#   inflating: dataset/Validation/G/_1_76.jpg
#   inflating: dataset/Validation/G/_1_77.jpg
#   inflating: dataset/Validation/G/_1_78.jpg
#   inflating: dataset/Validation/G/_1_79.jpg
#   inflating: dataset/Validation/G/_1_8.jpg
#   inflating: dataset/Validation/G/_1_80.jpg
#   inflating: dataset/Validation/G/_1_81.jpg
#   inflating: dataset/Validation/G/_1_82.jpg
#   inflating: dataset/Validation/G/_1_83.jpg
#   inflating: dataset/Validation/G/_1_84.jpg
#   inflating: dataset/Validation/G/_1_85.jpg
#   inflating: dataset/Validation/G/_1_86.jpg
#   inflating: dataset/Validation/G/_1_87.jpg
#   inflating: dataset/Validation/G/_1_88.jpg
#   inflating: dataset/Validation/G/_1_89.jpg
#   inflating: dataset/Validation/G/_1_9.jpg
#   inflating: dataset/Validation/G/_1_90.jpg
#   inflating: dataset/Validation/G/_1_91.jpg
#   inflating: dataset/Validation/G/_1_92.jpg
#   inflating: dataset/Validation/G/_1_93.jpg
#   inflating: dataset/Validation/G/_1_94.jpg
#   inflating: dataset/Validation/G/_1_95.jpg
#   inflating: dataset/Validation/G/_1_96.jpg
#   inflating: dataset/Validation/G/_1_97.jpg
#   inflating: dataset/Validation/G/_1_98.jpg
#   inflating: dataset/Validation/G/_1_99.jpg
#   inflating: dataset/Validation/H/0.jpg
#   inflating: dataset/Validation/H/1.jpg
#   inflating: dataset/Validation/H/10.jpg
#   inflating: dataset/Validation/H/100.jpg
#   inflating: dataset/Validation/H/101.jpg
#   inflating: dataset/Validation/H/102.jpg
#   inflating: dataset/Validation/H/103.jpg
#   inflating: dataset/Validation/H/104.jpg
#   inflating: dataset/Validation/H/105.jpg
#   inflating: dataset/Validation/H/106.jpg
#   inflating: dataset/Validation/H/107.jpg
#   inflating: dataset/Validation/H/108.jpg
#   inflating: dataset/Validation/H/109.jpg
#   inflating: dataset/Validation/H/11.jpg
#   inflating: dataset/Validation/H/110.jpg
#   inflating: dataset/Validation/H/111.jpg
#   inflating: dataset/Validation/H/112.jpg
#   inflating: dataset/Validation/H/113.jpg
#   inflating: dataset/Validation/H/114.jpg
#   inflating: dataset/Validation/H/115.jpg
#   inflating: dataset/Validation/H/116.jpg
#   inflating: dataset/Validation/H/117.jpg
#   inflating: dataset/Validation/H/118.jpg
#   inflating: dataset/Validation/H/119.jpg
#   inflating: dataset/Validation/H/12.jpg
#   inflating: dataset/Validation/H/120.jpg
#   inflating: dataset/Validation/H/121.jpg
#   inflating: dataset/Validation/H/122.jpg
#   inflating: dataset/Validation/H/123.jpg
#   inflating: dataset/Validation/H/124.jpg
#   inflating: dataset/Validation/H/125.jpg
#   inflating: dataset/Validation/H/126.jpg
#   inflating: dataset/Validation/H/127.jpg
#   inflating: dataset/Validation/H/128.jpg
#   inflating: dataset/Validation/H/129.jpg
#   inflating: dataset/Validation/H/13.jpg
#   inflating: dataset/Validation/H/130.jpg
#   inflating: dataset/Validation/H/131.jpg
#   inflating: dataset/Validation/H/132.jpg
#   inflating: dataset/Validation/H/133.jpg
#   inflating: dataset/Validation/H/134.jpg
#   inflating: dataset/Validation/H/135.jpg
#   inflating: dataset/Validation/H/136.jpg
#   inflating: dataset/Validation/H/137.jpg
#   inflating: dataset/Validation/H/138.jpg
#   inflating: dataset/Validation/H/139.jpg
#   inflating: dataset/Validation/H/14.jpg
#   inflating: dataset/Validation/H/140.jpg
#   inflating: dataset/Validation/H/141.jpg
#   inflating: dataset/Validation/H/142.jpg
#   inflating: dataset/Validation/H/143.jpg
#   inflating: dataset/Validation/H/144.jpg
#   inflating: dataset/Validation/H/145.jpg
#   inflating: dataset/Validation/H/146.jpg
#   inflating: dataset/Validation/H/147.jpg
#   inflating: dataset/Validation/H/148.jpg
#   inflating: dataset/Validation/H/149.jpg
#   inflating: dataset/Validation/H/15.jpg
#   inflating: dataset/Validation/H/150.jpg
#   inflating: dataset/Validation/H/151.jpg
#   inflating: dataset/Validation/H/152.jpg
#   inflating: dataset/Validation/H/153.jpg
#   inflating: dataset/Validation/H/154.jpg
#   inflating: dataset/Validation/H/155.jpg
#   inflating: dataset/Validation/H/156.jpg
#   inflating: dataset/Validation/H/157.jpg
#   inflating: dataset/Validation/H/158.jpg
#   inflating: dataset/Validation/H/159.jpg
#   inflating: dataset/Validation/H/16.jpg
#   inflating: dataset/Validation/H/160.jpg
#   inflating: dataset/Validation/H/161.jpg
#   inflating: dataset/Validation/H/162.jpg
#   inflating: dataset/Validation/H/163.jpg
#   inflating: dataset/Validation/H/164.jpg
#   inflating: dataset/Validation/H/165.jpg
#   inflating: dataset/Validation/H/166.jpg
#   inflating: dataset/Validation/H/167.jpg
#   inflating: dataset/Validation/H/168.jpg
#   inflating: dataset/Validation/H/169.jpg
#   inflating: dataset/Validation/H/17.jpg
#   inflating: dataset/Validation/H/170.jpg
#   inflating: dataset/Validation/H/171.jpg
#   inflating: dataset/Validation/H/172.jpg
#   inflating: dataset/Validation/H/173.jpg
#   inflating: dataset/Validation/H/174.jpg
#   inflating: dataset/Validation/H/175.jpg
#   inflating: dataset/Validation/H/176.jpg
#   inflating: dataset/Validation/H/177.jpg
#   inflating: dataset/Validation/H/178.jpg
#   inflating: dataset/Validation/H/179.jpg
#   inflating: dataset/Validation/H/18.jpg
#   inflating: dataset/Validation/H/180.jpg
#   inflating: dataset/Validation/H/181.jpg
#   inflating: dataset/Validation/H/19.jpg
#   inflating: dataset/Validation/H/2.jpg
#   inflating: dataset/Validation/H/20.jpg
#   inflating: dataset/Validation/H/21.jpg
#   inflating: dataset/Validation/H/22.jpg
#   inflating: dataset/Validation/H/23.jpg
#   inflating: dataset/Validation/H/24.jpg
#   inflating: dataset/Validation/H/25.jpg
#   inflating: dataset/Validation/H/26.jpg
#   inflating: dataset/Validation/H/27.jpg
#   inflating: dataset/Validation/H/28.jpg
#   inflating: dataset/Validation/H/29.jpg
#   inflating: dataset/Validation/H/3.jpg
#   inflating: dataset/Validation/H/30.jpg
#   inflating: dataset/Validation/H/31.jpg
#   inflating: dataset/Validation/H/32.jpg
#   inflating: dataset/Validation/H/33.jpg
#   inflating: dataset/Validation/H/34.jpg
#   inflating: dataset/Validation/H/35.jpg
#   inflating: dataset/Validation/H/36.jpg
#   inflating: dataset/Validation/H/37.jpg
#   inflating: dataset/Validation/H/38.jpg
#   inflating: dataset/Validation/H/39.jpg
#   inflating: dataset/Validation/H/4.jpg
#   inflating: dataset/Validation/H/40.jpg
#   inflating: dataset/Validation/H/41.jpg
#   inflating: dataset/Validation/H/42.jpg
#   inflating: dataset/Validation/H/43.jpg
#   inflating: dataset/Validation/H/44.jpg
#   inflating: dataset/Validation/H/45.jpg
#   inflating: dataset/Validation/H/46.jpg
#   inflating: dataset/Validation/H/47.jpg
#   inflating: dataset/Validation/H/48.jpg
#   inflating: dataset/Validation/H/49.jpg
#   inflating: dataset/Validation/H/5.jpg
#   inflating: dataset/Validation/H/50.jpg
#   inflating: dataset/Validation/H/51.jpg
#   inflating: dataset/Validation/H/52.jpg
#   inflating: dataset/Validation/H/53.jpg
#   inflating: dataset/Validation/H/54.jpg
#   inflating: dataset/Validation/H/55.jpg
#   inflating: dataset/Validation/H/56.jpg
#   inflating: dataset/Validation/H/57.jpg
#   inflating: dataset/Validation/H/58.jpg
#   inflating: dataset/Validation/H/59.jpg
#   inflating: dataset/Validation/H/6.jpg
#   inflating: dataset/Validation/H/60.jpg
#   inflating: dataset/Validation/H/61.jpg
#   inflating: dataset/Validation/H/62.jpg
#   inflating: dataset/Validation/H/63.jpg
#   inflating: dataset/Validation/H/64.jpg
#   inflating: dataset/Validation/H/65.jpg
#   inflating: dataset/Validation/H/66.jpg
#   inflating: dataset/Validation/H/67.jpg
#   inflating: dataset/Validation/H/68.jpg
#   inflating: dataset/Validation/H/69.jpg
#   inflating: dataset/Validation/H/7.jpg
#   inflating: dataset/Validation/H/70.jpg
#   inflating: dataset/Validation/H/71.jpg
#   inflating: dataset/Validation/H/72.jpg
#   inflating: dataset/Validation/H/73.jpg
#   inflating: dataset/Validation/H/74.jpg
#   inflating: dataset/Validation/H/75.jpg
#   inflating: dataset/Validation/H/76.jpg
#   inflating: dataset/Validation/H/77.jpg
#   inflating: dataset/Validation/H/78.jpg
#   inflating: dataset/Validation/H/79.jpg
#   inflating: dataset/Validation/H/8.jpg
#   inflating: dataset/Validation/H/80.jpg
#   inflating: dataset/Validation/H/81.jpg
#   inflating: dataset/Validation/H/82.jpg
#   inflating: dataset/Validation/H/83.jpg
#   inflating: dataset/Validation/H/84.jpg
#   inflating: dataset/Validation/H/85.jpg
#   inflating: dataset/Validation/H/86.jpg
#   inflating: dataset/Validation/H/87.jpg
#   inflating: dataset/Validation/H/88.jpg
#   inflating: dataset/Validation/H/89.jpg
#   inflating: dataset/Validation/H/9.jpg
#   inflating: dataset/Validation/H/90.jpg
#   inflating: dataset/Validation/H/91.jpg
#   inflating: dataset/Validation/H/92.jpg
#   inflating: dataset/Validation/H/93.jpg
#   inflating: dataset/Validation/H/94.jpg
#   inflating: dataset/Validation/H/95.jpg
#   inflating: dataset/Validation/H/96.jpg
#   inflating: dataset/Validation/H/97.jpg
#   inflating: dataset/Validation/H/98.jpg
#   inflating: dataset/Validation/H/99.jpg
#   inflating: dataset/Validation/H/_1_0.jpg
#   inflating: dataset/Validation/H/_1_1.jpg
#   inflating: dataset/Validation/H/_1_10.jpg
#   inflating: dataset/Validation/H/_1_100.jpg
#   inflating: dataset/Validation/H/_1_101.jpg
#   inflating: dataset/Validation/H/_1_102.jpg
#   inflating: dataset/Validation/H/_1_103.jpg
#   inflating: dataset/Validation/H/_1_104.jpg
#   inflating: dataset/Validation/H/_1_105.jpg
#   inflating: dataset/Validation/H/_1_106.jpg
#   inflating: dataset/Validation/H/_1_107.jpg
#   inflating: dataset/Validation/H/_1_108.jpg
#   inflating: dataset/Validation/H/_1_109.jpg
#   inflating: dataset/Validation/H/_1_11.jpg
#   inflating: dataset/Validation/H/_1_110.jpg
#   inflating: dataset/Validation/H/_1_111.jpg
#   inflating: dataset/Validation/H/_1_112.jpg
#   inflating: dataset/Validation/H/_1_113.jpg
#   inflating: dataset/Validation/H/_1_114.jpg
#   inflating: dataset/Validation/H/_1_115.jpg
#   inflating: dataset/Validation/H/_1_116.jpg
#   inflating: dataset/Validation/H/_1_117.jpg
#   inflating: dataset/Validation/H/_1_118.jpg
#   inflating: dataset/Validation/H/_1_119.jpg
#   inflating: dataset/Validation/H/_1_12.jpg
#   inflating: dataset/Validation/H/_1_120.jpg
#   inflating: dataset/Validation/H/_1_121.jpg
#   inflating: dataset/Validation/H/_1_122.jpg
#   inflating: dataset/Validation/H/_1_123.jpg
#   inflating: dataset/Validation/H/_1_124.jpg
#   inflating: dataset/Validation/H/_1_125.jpg
#   inflating: dataset/Validation/H/_1_126.jpg
#   inflating: dataset/Validation/H/_1_127.jpg
#   inflating: dataset/Validation/H/_1_128.jpg
#   inflating: dataset/Validation/H/_1_129.jpg
#   inflating: dataset/Validation/H/_1_13.jpg
#   inflating: dataset/Validation/H/_1_130.jpg
#   inflating: dataset/Validation/H/_1_131.jpg
#   inflating: dataset/Validation/H/_1_132.jpg
#   inflating: dataset/Validation/H/_1_133.jpg
#   inflating: dataset/Validation/H/_1_134.jpg
#   inflating: dataset/Validation/H/_1_135.jpg
#   inflating: dataset/Validation/H/_1_136.jpg
#   inflating: dataset/Validation/H/_1_137.jpg
#   inflating: dataset/Validation/H/_1_138.jpg
#   inflating: dataset/Validation/H/_1_139.jpg
#   inflating: dataset/Validation/H/_1_14.jpg
#   inflating: dataset/Validation/H/_1_140.jpg
#   inflating: dataset/Validation/H/_1_141.jpg
#   inflating: dataset/Validation/H/_1_142.jpg
#   inflating: dataset/Validation/H/_1_143.jpg
#   inflating: dataset/Validation/H/_1_144.jpg
#   inflating: dataset/Validation/H/_1_145.jpg
#   inflating: dataset/Validation/H/_1_146.jpg
#   inflating: dataset/Validation/H/_1_147.jpg
#   inflating: dataset/Validation/H/_1_148.jpg
#   inflating: dataset/Validation/H/_1_149.jpg
#   inflating: dataset/Validation/H/_1_15.jpg
#   inflating: dataset/Validation/H/_1_150.jpg
#   inflating: dataset/Validation/H/_1_151.jpg
#   inflating: dataset/Validation/H/_1_152.jpg
#   inflating: dataset/Validation/H/_1_153.jpg
#   inflating: dataset/Validation/H/_1_154.jpg
#   inflating: dataset/Validation/H/_1_155.jpg
#   inflating: dataset/Validation/H/_1_156.jpg
#   inflating: dataset/Validation/H/_1_157.jpg
#   inflating: dataset/Validation/H/_1_158.jpg
#   inflating: dataset/Validation/H/_1_159.jpg
#   inflating: dataset/Validation/H/_1_16.jpg
#   inflating: dataset/Validation/H/_1_160.jpg
#   inflating: dataset/Validation/H/_1_17.jpg
#   inflating: dataset/Validation/H/_1_18.jpg
#   inflating: dataset/Validation/H/_1_19.jpg
#   inflating: dataset/Validation/H/_1_2.jpg
#   inflating: dataset/Validation/H/_1_20.jpg
#   inflating: dataset/Validation/H/_1_21.jpg
#   inflating: dataset/Validation/H/_1_22.jpg
#   inflating: dataset/Validation/H/_1_23.jpg
#   inflating: dataset/Validation/H/_1_24.jpg
#   inflating: dataset/Validation/H/_1_25.jpg
#   inflating: dataset/Validation/H/_1_26.jpg
#   inflating: dataset/Validation/H/_1_27.jpg
#   inflating: dataset/Validation/H/_1_28.jpg
#   inflating: dataset/Validation/H/_1_29.jpg
#   inflating: dataset/Validation/H/_1_3.jpg
#   inflating: dataset/Validation/H/_1_30.jpg
#   inflating: dataset/Validation/H/_1_31.jpg
#   inflating: dataset/Validation/H/_1_32.jpg
#   inflating: dataset/Validation/H/_1_33.jpg
#   inflating: dataset/Validation/H/_1_34.jpg
#   inflating: dataset/Validation/H/_1_35.jpg
#   inflating: dataset/Validation/H/_1_36.jpg
#   inflating: dataset/Validation/H/_1_37.jpg
#   inflating: dataset/Validation/H/_1_38.jpg
#   inflating: dataset/Validation/H/_1_39.jpg
#   inflating: dataset/Validation/H/_1_4.jpg
#   inflating: dataset/Validation/H/_1_40.jpg
#   inflating: dataset/Validation/H/_1_41.jpg
#   inflating: dataset/Validation/H/_1_42.jpg
#   inflating: dataset/Validation/H/_1_43.jpg
#   inflating: dataset/Validation/H/_1_44.jpg
#   inflating: dataset/Validation/H/_1_45.jpg
#   inflating: dataset/Validation/H/_1_46.jpg
#   inflating: dataset/Validation/H/_1_47.jpg
#   inflating: dataset/Validation/H/_1_48.jpg
#   inflating: dataset/Validation/H/_1_49.jpg
#   inflating: dataset/Validation/H/_1_5.jpg
#   inflating: dataset/Validation/H/_1_50.jpg
#   inflating: dataset/Validation/H/_1_51.jpg
#   inflating: dataset/Validation/H/_1_52.jpg
#   inflating: dataset/Validation/H/_1_53.jpg
#   inflating: dataset/Validation/H/_1_54.jpg
#   inflating: dataset/Validation/H/_1_55.jpg
#   inflating: dataset/Validation/H/_1_56.jpg
#   inflating: dataset/Validation/H/_1_57.jpg
#   inflating: dataset/Validation/H/_1_58.jpg
#   inflating: dataset/Validation/H/_1_59.jpg
#   inflating: dataset/Validation/H/_1_6.jpg
#   inflating: dataset/Validation/H/_1_60.jpg
#   inflating: dataset/Validation/H/_1_61.jpg
#   inflating: dataset/Validation/H/_1_62.jpg
#   inflating: dataset/Validation/H/_1_63.jpg
#   inflating: dataset/Validation/H/_1_64.jpg
#   inflating: dataset/Validation/H/_1_65.jpg
#   inflating: dataset/Validation/H/_1_66.jpg
#   inflating: dataset/Validation/H/_1_67.jpg
#   inflating: dataset/Validation/H/_1_68.jpg
#   inflating: dataset/Validation/H/_1_69.jpg
#   inflating: dataset/Validation/H/_1_7.jpg
#   inflating: dataset/Validation/H/_1_70.jpg
#   inflating: dataset/Validation/H/_1_71.jpg
#   inflating: dataset/Validation/H/_1_72.jpg
#   inflating: dataset/Validation/H/_1_73.jpg
#   inflating: dataset/Validation/H/_1_74.jpg
#   inflating: dataset/Validation/H/_1_75.jpg
#   inflating: dataset/Validation/H/_1_76.jpg
#   inflating: dataset/Validation/H/_1_77.jpg
#   inflating: dataset/Validation/H/_1_78.jpg
#   inflating: dataset/Validation/H/_1_79.jpg
#   inflating: dataset/Validation/H/_1_8.jpg
#   inflating: dataset/Validation/H/_1_80.jpg
#   inflating: dataset/Validation/H/_1_81.jpg
#   inflating: dataset/Validation/H/_1_82.jpg
#   inflating: dataset/Validation/H/_1_83.jpg
#   inflating: dataset/Validation/H/_1_84.jpg
#   inflating: dataset/Validation/H/_1_85.jpg
#   inflating: dataset/Validation/H/_1_86.jpg
#   inflating: dataset/Validation/H/_1_87.jpg
#   inflating: dataset/Validation/H/_1_88.jpg
#   inflating: dataset/Validation/H/_1_89.jpg
#   inflating: dataset/Validation/H/_1_9.jpg
#   inflating: dataset/Validation/H/_1_90.jpg
#   inflating: dataset/Validation/H/_1_91.jpg
#   inflating: dataset/Validation/H/_1_92.jpg
#   inflating: dataset/Validation/H/_1_93.jpg
#   inflating: dataset/Validation/H/_1_94.jpg
#   inflating: dataset/Validation/H/_1_95.jpg
#   inflating: dataset/Validation/H/_1_96.jpg
#   inflating: dataset/Validation/H/_1_97.jpg
#   inflating: dataset/Validation/H/_1_98.jpg
#   inflating: dataset/Validation/H/_1_99.jpg
#   inflating: dataset/Validation/I/0.jpg
#   inflating: dataset/Validation/I/1.jpg
#   inflating: dataset/Validation/I/10.jpg
#   inflating: dataset/Validation/I/100.jpg
#   inflating: dataset/Validation/I/101.jpg
#   inflating: dataset/Validation/I/102.jpg
#   inflating: dataset/Validation/I/103.jpg
#   inflating: dataset/Validation/I/104.jpg
#   inflating: dataset/Validation/I/105.jpg
#   inflating: dataset/Validation/I/106.jpg
#   inflating: dataset/Validation/I/107.jpg
#   inflating: dataset/Validation/I/108.jpg
#   inflating: dataset/Validation/I/109.jpg
#   inflating: dataset/Validation/I/11.jpg
#   inflating: dataset/Validation/I/110.jpg
#   inflating: dataset/Validation/I/111.jpg
#   inflating: dataset/Validation/I/112.jpg
#   inflating: dataset/Validation/I/113.jpg
#   inflating: dataset/Validation/I/114.jpg
#   inflating: dataset/Validation/I/115.jpg
#   inflating: dataset/Validation/I/116.jpg
#   inflating: dataset/Validation/I/117.jpg
#   inflating: dataset/Validation/I/118.jpg
#   inflating: dataset/Validation/I/119.jpg
#   inflating: dataset/Validation/I/12.jpg
#   inflating: dataset/Validation/I/120.jpg
#   inflating: dataset/Validation/I/121.jpg
#   inflating: dataset/Validation/I/122.jpg
#   inflating: dataset/Validation/I/123.jpg
#   inflating: dataset/Validation/I/124.jpg
#   inflating: dataset/Validation/I/125.jpg
#   inflating: dataset/Validation/I/126.jpg
#   inflating: dataset/Validation/I/127.jpg
#   inflating: dataset/Validation/I/128.jpg
#   inflating: dataset/Validation/I/129.jpg
#   inflating: dataset/Validation/I/13.jpg
#   inflating: dataset/Validation/I/130.jpg
#   inflating: dataset/Validation/I/131.jpg
#   inflating: dataset/Validation/I/132.jpg
#   inflating: dataset/Validation/I/133.jpg
#   inflating: dataset/Validation/I/134.jpg
#   inflating: dataset/Validation/I/135.jpg
#   inflating: dataset/Validation/I/136.jpg
#   inflating: dataset/Validation/I/137.jpg
#   inflating: dataset/Validation/I/138.jpg
#   inflating: dataset/Validation/I/139.jpg
#   inflating: dataset/Validation/I/14.jpg
#   inflating: dataset/Validation/I/140.jpg
#   inflating: dataset/Validation/I/141.jpg
#   inflating: dataset/Validation/I/142.jpg
#   inflating: dataset/Validation/I/143.jpg
#   inflating: dataset/Validation/I/144.jpg
#   inflating: dataset/Validation/I/145.jpg
#   inflating: dataset/Validation/I/146.jpg
#   inflating: dataset/Validation/I/147.jpg
#   inflating: dataset/Validation/I/148.jpg
#   inflating: dataset/Validation/I/149.jpg
#   inflating: dataset/Validation/I/15.jpg
#   inflating: dataset/Validation/I/150.jpg
#   inflating: dataset/Validation/I/151.jpg
#   inflating: dataset/Validation/I/152.jpg
#   inflating: dataset/Validation/I/153.jpg
#   inflating: dataset/Validation/I/154.jpg
#   inflating: dataset/Validation/I/155.jpg
#   inflating: dataset/Validation/I/156.jpg
#   inflating: dataset/Validation/I/157.jpg
#   inflating: dataset/Validation/I/158.jpg
#   inflating: dataset/Validation/I/159.jpg
#   inflating: dataset/Validation/I/16.jpg
#   inflating: dataset/Validation/I/160.jpg
#   inflating: dataset/Validation/I/161.jpg
#   inflating: dataset/Validation/I/162.jpg
#   inflating: dataset/Validation/I/163.jpg
#   inflating: dataset/Validation/I/164.jpg
#   inflating: dataset/Validation/I/165.jpg
#   inflating: dataset/Validation/I/166.jpg
#   inflating: dataset/Validation/I/167.jpg
#   inflating: dataset/Validation/I/168.jpg
#   inflating: dataset/Validation/I/169.jpg
#   inflating: dataset/Validation/I/17.jpg
#   inflating: dataset/Validation/I/170.jpg
#   inflating: dataset/Validation/I/171.jpg
#   inflating: dataset/Validation/I/172.jpg
#   inflating: dataset/Validation/I/173.jpg
#   inflating: dataset/Validation/I/174.jpg
#   inflating: dataset/Validation/I/175.jpg
#   inflating: dataset/Validation/I/176.jpg
#   inflating: dataset/Validation/I/177.jpg
#   inflating: dataset/Validation/I/178.jpg
#   inflating: dataset/Validation/I/179.jpg
#   inflating: dataset/Validation/I/18.jpg
#   inflating: dataset/Validation/I/180.jpg
#   inflating: dataset/Validation/I/181.jpg
#   inflating: dataset/Validation/I/182.jpg
#   inflating: dataset/Validation/I/183.jpg
#   inflating: dataset/Validation/I/184.jpg
#   inflating: dataset/Validation/I/185.jpg
#   inflating: dataset/Validation/I/186.jpg
#   inflating: dataset/Validation/I/187.jpg
#   inflating: dataset/Validation/I/188.jpg
#   inflating: dataset/Validation/I/189.jpg
#   inflating: dataset/Validation/I/19.jpg
#   inflating: dataset/Validation/I/190.jpg
#   inflating: dataset/Validation/I/191.jpg
#   inflating: dataset/Validation/I/192.jpg
#   inflating: dataset/Validation/I/193.jpg
#   inflating: dataset/Validation/I/194.jpg
#   inflating: dataset/Validation/I/195.jpg
#   inflating: dataset/Validation/I/196.jpg
#   inflating: dataset/Validation/I/197.jpg
#   inflating: dataset/Validation/I/198.jpg
#   inflating: dataset/Validation/I/199.jpg
#   inflating: dataset/Validation/I/2.jpg
#   inflating: dataset/Validation/I/20.jpg
#   inflating: dataset/Validation/I/200.jpg
#   inflating: dataset/Validation/I/201.jpg
# ...
#   inflating: dataset/Validation/Y/10.jpg
#   inflating: dataset/Validation/Y/100.jpg
#   inflating: dataset/Validation/Y/101.jpg
#   inflating: dataset/Validation/Y/102.jpg
#   inflating: dataset/Validation/Y/103.jpg
#   inflating: dataset/Validation/Y/104.jpg
#   inflating: dataset/Validation/Y/105.jpg
#   inflating: dataset/Validation/Y/106.jpg
#   inflating: dataset/Validation/Y/107.jpg
#   inflating: dataset/Validation/Y/108.jpg
#   inflating: dataset/Validation/Y/109.jpg
#   inflating: dataset/Validation/Y/11.jpg
#   inflating: dataset/Validation/Y/110.jpg
#   inflating: dataset/Validation/Y/111.jpg
#   inflating: dataset/Validation/Y/112.jpg
#   inflating: dataset/Validation/Y/113.jpg
#   inflating: dataset/Validation/Y/114.jpg
#   inflating: dataset/Validation/Y/115.jpg
#   inflating: dataset/Validation/Y/116.jpg
#   inflating: dataset/Validation/Y/117.jpg
#   inflating: dataset/Validation/Y/118.jpg
#   inflating: dataset/Validation/Y/119.jpg
#   inflating: dataset/Validation/Y/12.jpg
#   inflating: dataset/Validation/Y/120.jpg
#   inflating: dataset/Validation/Y/121.jpg
#   inflating: dataset/Validation/Y/122.jpg
#   inflating: dataset/Validation/Y/123.jpg
#   inflating: dataset/Validation/Y/124.jpg
#   inflating: dataset/Validation/Y/125.jpg
#   inflating: dataset/Validation/Y/126.jpg
#   inflating: dataset/Validation/Y/127.jpg
#   inflating: dataset/Validation/Y/128.jpg
#   inflating: dataset/Validation/Y/129.jpg
#   inflating: dataset/Validation/Y/13.jpg
#   inflating: dataset/Validation/Y/130.jpg
#   inflating: dataset/Validation/Y/131.jpg
#   inflating: dataset/Validation/Y/132.jpg
#   inflating: dataset/Validation/Y/133.jpg
#   inflating: dataset/Validation/Y/134.jpg
#   inflating: dataset/Validation/Y/135.jpg
#   inflating: dataset/Validation/Y/136.jpg
#   inflating: dataset/Validation/Y/137.jpg
#   inflating: dataset/Validation/Y/138.jpg
#   inflating: dataset/Validation/Y/139.jpg
#   inflating: dataset/Validation/Y/14.jpg
#   inflating: dataset/Validation/Y/140.jpg
#   inflating: dataset/Validation/Y/141.jpg
#   inflating: dataset/Validation/Y/142.jpg
#   inflating: dataset/Validation/Y/143.jpg
#   inflating: dataset/Validation/Y/144.jpg
#   inflating: dataset/Validation/Y/145.jpg
#   inflating: dataset/Validation/Y/146.jpg
#   inflating: dataset/Validation/Y/147.jpg
#   inflating: dataset/Validation/Y/148.jpg
#   inflating: dataset/Validation/Y/149.jpg
#   inflating: dataset/Validation/Y/15.jpg
#   inflating: dataset/Validation/Y/150.jpg
#   inflating: dataset/Validation/Y/151.jpg
#   inflating: dataset/Validation/Y/152.jpg
#   inflating: dataset/Validation/Y/153.jpg
#   inflating: dataset/Validation/Y/154.jpg
#   inflating: dataset/Validation/Y/155.jpg
#   inflating: dataset/Validation/Y/156.jpg
#   inflating: dataset/Validation/Y/157.jpg
#   inflating: dataset/Validation/Y/158.jpg
#   inflating: dataset/Validation/Y/159.jpg
#   inflating: dataset/Validation/Y/16.jpg
#   inflating: dataset/Validation/Y/160.jpg
#   inflating: dataset/Validation/Y/161.jpg
#   inflating: dataset/Validation/Y/162.jpg
#   inflating: dataset/Validation/Y/163.jpg
#   inflating: dataset/Validation/Y/164.jpg
#   inflating: dataset/Validation/Y/165.jpg
#   inflating: dataset/Validation/Y/166.jpg
#   inflating: dataset/Validation/Y/167.jpg
#   inflating: dataset/Validation/Y/168.jpg
#   inflating: dataset/Validation/Y/169.jpg
#   inflating: dataset/Validation/Y/17.jpg
#   inflating: dataset/Validation/Y/170.jpg
#   inflating: dataset/Validation/Y/171.jpg
#   inflating: dataset/Validation/Y/172.jpg
#   inflating: dataset/Validation/Y/173.jpg
#   inflating: dataset/Validation/Y/174.jpg
#   inflating: dataset/Validation/Y/175.jpg
#   inflating: dataset/Validation/Y/176.jpg
#   inflating: dataset/Validation/Y/177.jpg
#   inflating: dataset/Validation/Y/178.jpg
#   inflating: dataset/Validation/Y/179.jpg
#   inflating: dataset/Validation/Y/18.jpg
#   inflating: dataset/Validation/Y/180.jpg
#   inflating: dataset/Validation/Y/181.jpg
#   inflating: dataset/Validation/Y/182.jpg
#   inflating: dataset/Validation/Y/183.jpg
#   inflating: dataset/Validation/Y/184.jpg
#   inflating: dataset/Validation/Y/185.jpg
#   inflating: dataset/Validation/Y/186.jpg
#   inflating: dataset/Validation/Y/187.jpg
#   inflating: dataset/Validation/Y/188.jpg
#   inflating: dataset/Validation/Y/19.jpg
#   inflating: dataset/Validation/Y/2.jpg
#   inflating: dataset/Validation/Y/20.jpg
#   inflating: dataset/Validation/Y/21.jpg
#   inflating: dataset/Validation/Y/22.jpg
#   inflating: dataset/Validation/Y/23.jpg
#   inflating: dataset/Validation/Y/24.jpg
#   inflating: dataset/Validation/Y/25.jpg
#   inflating: dataset/Validation/Y/26.jpg
#   inflating: dataset/Validation/Y/27.jpg
#   inflating: dataset/Validation/Y/28.jpg
#   inflating: dataset/Validation/Y/29.jpg
#   inflating: dataset/Validation/Y/3.jpg
#   inflating: dataset/Validation/Y/30.jpg
#   inflating: dataset/Validation/Y/31.jpg
#   inflating: dataset/Validation/Y/32.jpg
#   inflating: dataset/Validation/Y/33.jpg
#   inflating: dataset/Validation/Y/34.jpg
#   inflating: dataset/Validation/Y/35.jpg
#   inflating: dataset/Validation/Y/36.jpg
#   inflating: dataset/Validation/Y/37.jpg
#   inflating: dataset/Validation/Y/38.jpg
#   inflating: dataset/Validation/Y/39.jpg
#   inflating: dataset/Validation/Y/4.jpg
#   inflating: dataset/Validation/Y/40.jpg
#   inflating: dataset/Validation/Y/41.jpg
#   inflating: dataset/Validation/Y/42.jpg
#   inflating: dataset/Validation/Y/43.jpg
#   inflating: dataset/Validation/Y/44.jpg
#   inflating: dataset/Validation/Y/45.jpg
#   inflating: dataset/Validation/Y/46.jpg
#   inflating: dataset/Validation/Y/47.jpg
#   inflating: dataset/Validation/Y/48.jpg
#   inflating: dataset/Validation/Y/49.jpg
#   inflating: dataset/Validation/Y/5.jpg
#   inflating: dataset/Validation/Y/50.jpg
#   inflating: dataset/Validation/Y/51.jpg
#   inflating: dataset/Validation/Y/52.jpg
#   inflating: dataset/Validation/Y/53.jpg
#   inflating: dataset/Validation/Y/54.jpg
#   inflating: dataset/Validation/Y/55.jpg
#   inflating: dataset/Validation/Y/56.jpg
#   inflating: dataset/Validation/Y/57.jpg
#   inflating: dataset/Validation/Y/58.jpg
#   inflating: dataset/Validation/Y/59.jpg
#   inflating: dataset/Validation/Y/6.jpg
#   inflating: dataset/Validation/Y/60.jpg
#   inflating: dataset/Validation/Y/61.jpg
#   inflating: dataset/Validation/Y/62.jpg
#   inflating: dataset/Validation/Y/63.jpg
#   inflating: dataset/Validation/Y/64.jpg
#   inflating: dataset/Validation/Y/65.jpg
#   inflating: dataset/Validation/Y/66.jpg
#   inflating: dataset/Validation/Y/67.jpg
#   inflating: dataset/Validation/Y/68.jpg
#   inflating: dataset/Validation/Y/69.jpg
#   inflating: dataset/Validation/Y/7.jpg
#   inflating: dataset/Validation/Y/70.jpg
#   inflating: dataset/Validation/Y/71.jpg
#   inflating: dataset/Validation/Y/72.jpg
#   inflating: dataset/Validation/Y/73.jpg
#   inflating: dataset/Validation/Y/74.jpg
#   inflating: dataset/Validation/Y/75.jpg
#   inflating: dataset/Validation/Y/76.jpg
#   inflating: dataset/Validation/Y/77.jpg
#   inflating: dataset/Validation/Y/78.jpg
#   inflating: dataset/Validation/Y/79.jpg
#   inflating: dataset/Validation/Y/8.jpg
#   inflating: dataset/Validation/Y/80.jpg
#   inflating: dataset/Validation/Y/81.jpg
#   inflating: dataset/Validation/Y/82.jpg
#   inflating: dataset/Validation/Y/83.jpg
#   inflating: dataset/Validation/Y/84.jpg
#   inflating: dataset/Validation/Y/85.jpg
#   inflating: dataset/Validation/Y/86.jpg
#   inflating: dataset/Validation/Y/87.jpg
#   inflating: dataset/Validation/Y/88.jpg
#   inflating: dataset/Validation/Y/89.jpg
#   inflating: dataset/Validation/Y/9.jpg
#   inflating: dataset/Validation/Y/90.jpg
#   inflating: dataset/Validation/Y/91.jpg
#   inflating: dataset/Validation/Y/92.jpg
#   inflating: dataset/Validation/Y/93.jpg
#   inflating: dataset/Validation/Y/94.jpg
#   inflating: dataset/Validation/Y/95.jpg
#   inflating: dataset/Validation/Y/96.jpg
#   inflating: dataset/Validation/Y/97.jpg
#   inflating: dataset/Validation/Y/98.jpg
#   inflating: dataset/Validation/Y/99.jpg
#   inflating: dataset/Validation/Z/0.jpg
#   inflating: dataset/Validation/Z/1.jpg
#   inflating: dataset/Validation/Z/10.jpg
#   inflating: dataset/Validation/Z/100.jpg
#   inflating: dataset/Validation/Z/101.jpg
#   inflating: dataset/Validation/Z/102.jpg
#   inflating: dataset/Validation/Z/103.jpg
#   inflating: dataset/Validation/Z/104.jpg
#   inflating: dataset/Validation/Z/105.jpg
#   inflating: dataset/Validation/Z/106.jpg
#   inflating: dataset/Validation/Z/107.jpg
#   inflating: dataset/Validation/Z/108.jpg
#   inflating: dataset/Validation/Z/109.jpg
#   inflating: dataset/Validation/Z/11.jpg
#   inflating: dataset/Validation/Z/110.jpg
#   inflating: dataset/Validation/Z/111.jpg
#   inflating: dataset/Validation/Z/112.jpg
#   inflating: dataset/Validation/Z/113.jpg
#   inflating: dataset/Validation/Z/114.jpg
#   inflating: dataset/Validation/Z/115.jpg
#   inflating: dataset/Validation/Z/116.jpg
#   inflating: dataset/Validation/Z/117.jpg
#   inflating: dataset/Validation/Z/118.jpg
#   inflating: dataset/Validation/Z/119.jpg
#   inflating: dataset/Validation/Z/12.jpg
#   inflating: dataset/Validation/Z/120.jpg
#   inflating: dataset/Validation/Z/121.jpg
#   inflating: dataset/Validation/Z/122.jpg
#   inflating: dataset/Validation/Z/123.jpg
#   inflating: dataset/Validation/Z/124.jpg
#   inflating: dataset/Validation/Z/125.jpg
#   inflating: dataset/Validation/Z/126.jpg
#   inflating: dataset/Validation/Z/127.jpg
#   inflating: dataset/Validation/Z/128.jpg
#   inflating: dataset/Validation/Z/129.jpg
#   inflating: dataset/Validation/Z/13.jpg
#   inflating: dataset/Validation/Z/130.jpg
#   inflating: dataset/Validation/Z/131.jpg
#   inflating: dataset/Validation/Z/132.jpg
#   inflating: dataset/Validation/Z/133.jpg
#   inflating: dataset/Validation/Z/134.jpg
#   inflating: dataset/Validation/Z/135.jpg
#   inflating: dataset/Validation/Z/136.jpg
#   inflating: dataset/Validation/Z/137.jpg
#   inflating: dataset/Validation/Z/138.jpg
#   inflating: dataset/Validation/Z/139.jpg
#   inflating: dataset/Validation/Z/14.jpg
#   inflating: dataset/Validation/Z/140.jpg
#   inflating: dataset/Validation/Z/141.jpg
#   inflating: dataset/Validation/Z/142.jpg
#   inflating: dataset/Validation/Z/143.jpg
#   inflating: dataset/Validation/Z/144.jpg
#   inflating: dataset/Validation/Z/145.jpg
#   inflating: dataset/Validation/Z/146.jpg
#   inflating: dataset/Validation/Z/147.jpg
#   inflating: dataset/Validation/Z/148.jpg
#   inflating: dataset/Validation/Z/149.jpg
#   inflating: dataset/Validation/Z/15.jpg
#   inflating: dataset/Validation/Z/150.jpg
#   inflating: dataset/Validation/Z/151.jpg
#   inflating: dataset/Validation/Z/152.jpg
#   inflating: dataset/Validation/Z/153.jpg
#   inflating: dataset/Validation/Z/154.jpg
#   inflating: dataset/Validation/Z/155.jpg
#   inflating: dataset/Validation/Z/156.jpg
#   inflating: dataset/Validation/Z/157.jpg
#   inflating: dataset/Validation/Z/158.jpg
#   inflating: dataset/Validation/Z/159.jpg
#   inflating: dataset/Validation/Z/16.jpg
#   inflating: dataset/Validation/Z/160.jpg
#   inflating: dataset/Validation/Z/161.jpg
#   inflating: dataset/Validation/Z/162.jpg
#   inflating: dataset/Validation/Z/163.jpg
#   inflating: dataset/Validation/Z/164.jpg
#   inflating: dataset/Validation/Z/165.jpg
#   inflating: dataset/Validation/Z/166.jpg
#   inflating: dataset/Validation/Z/167.jpg
#   inflating: dataset/Validation/Z/168.jpg
#   inflating: dataset/Validation/Z/169.jpg
#   inflating: dataset/Validation/Z/17.jpg
#   inflating: dataset/Validation/Z/170.jpg
#   inflating: dataset/Validation/Z/171.jpg
#   inflating: dataset/Validation/Z/172.jpg
#   inflating: dataset/Validation/Z/173.jpg
#   inflating: dataset/Validation/Z/174.jpg
#   inflating: dataset/Validation/Z/175.jpg
#   inflating: dataset/Validation/Z/176.jpg
#   inflating: dataset/Validation/Z/177.jpg
#   inflating: dataset/Validation/Z/178.jpg
#   inflating: dataset/Validation/Z/179.jpg
#   inflating: dataset/Validation/Z/18.jpg
#   inflating: dataset/Validation/Z/180.jpg
#   inflating: dataset/Validation/Z/19.jpg
#   inflating: dataset/Validation/Z/2.jpg
#   inflating: dataset/Validation/Z/20.jpg
#   inflating: dataset/Validation/Z/21.jpg
#   inflating: dataset/Validation/Z/22.jpg
#   inflating: dataset/Validation/Z/23.jpg
#   inflating: dataset/Validation/Z/24.jpg
#   inflating: dataset/Validation/Z/25.jpg
#   inflating: dataset/Validation/Z/26.jpg
#   inflating: dataset/Validation/Z/27.jpg
#   inflating: dataset/Validation/Z/28.jpg
#   inflating: dataset/Validation/Z/29.jpg
#   inflating: dataset/Validation/Z/3.jpg
#   inflating: dataset/Validation/Z/30.jpg
#   inflating: dataset/Validation/Z/31.jpg
#   inflating: dataset/Validation/Z/32.jpg
#   inflating: dataset/Validation/Z/33.jpg
#   inflating: dataset/Validation/Z/34.jpg
#   inflating: dataset/Validation/Z/35.jpg
#   inflating: dataset/Validation/Z/36.jpg
#   inflating: dataset/Validation/Z/37.jpg
#   inflating: dataset/Validation/Z/38.jpg
#   inflating: dataset/Validation/Z/39.jpg
#   inflating: dataset/Validation/Z/4.jpg
#   inflating: dataset/Validation/Z/40.jpg
#   inflating: dataset/Validation/Z/41.jpg
#   inflating: dataset/Validation/Z/42.jpg
#   inflating: dataset/Validation/Z/43.jpg
#   inflating: dataset/Validation/Z/44.jpg
#   inflating: dataset/Validation/Z/45.jpg
#   inflating: dataset/Validation/Z/46.jpg
#   inflating: dataset/Validation/Z/47.jpg
#   inflating: dataset/Validation/Z/48.jpg
#   inflating: dataset/Validation/Z/49.jpg
#   inflating: dataset/Validation/Z/5.jpg
#   inflating: dataset/Validation/Z/50.jpg
#   inflating: dataset/Validation/Z/51.jpg
#   inflating: dataset/Validation/Z/52.jpg
#   inflating: dataset/Validation/Z/53.jpg
#   inflating: dataset/Validation/Z/54.jpg
#   inflating: dataset/Validation/Z/55.jpg
#   inflating: dataset/Validation/Z/56.jpg
#   inflating: dataset/Validation/Z/57.jpg
#   inflating: dataset/Validation/Z/58.jpg
#   inflating: dataset/Validation/Z/59.jpg
#   inflating: dataset/Validation/Z/6.jpg
#   inflating: dataset/Validation/Z/60.jpg
#   inflating: dataset/Validation/Z/61.jpg
#   inflating: dataset/Validation/Z/62.jpg
#   inflating: dataset/Validation/Z/63.jpg
#   inflating: dataset/Validation/Z/64.jpg
#   inflating: dataset/Validation/Z/65.jpg
#   inflating: dataset/Validation/Z/66.jpg
#   inflating: dataset/Validation/Z/67.jpg
#   inflating: dataset/Validation/Z/68.jpg
#   inflating: dataset/Validation/Z/69.jpg
#   inflating: dataset/Validation/Z/7.jpg
#   inflating: dataset/Validation/Z/70.jpg
#   inflating: dataset/Validation/Z/71.jpg
#   inflating: dataset/Validation/Z/72.jpg
#   inflating: dataset/Validation/Z/73.jpg
#   inflating: dataset/Validation/Z/74.jpg
#   inflating: dataset/Validation/Z/75.jpg
#   inflating: dataset/Validation/Z/76.jpg
#   inflating: dataset/Validation/Z/77.jpg
#   inflating: dataset/Validation/Z/78.jpg
#   inflating: dataset/Validation/Z/79.jpg
#   inflating: dataset/Validation/Z/8.jpg
#   inflating: dataset/Validation/Z/80.jpg
#   inflating: dataset/Validation/Z/81.jpg
#   inflating: dataset/Validation/Z/82.jpg
#   inflating: dataset/Validation/Z/83.jpg
#   inflating: dataset/Validation/Z/84.jpg
#   inflating: dataset/Validation/Z/85.jpg
#   inflating: dataset/Validation/Z/86.jpg
#   inflating: dataset/Validation/Z/87.jpg
#   inflating: dataset/Validation/Z/88.jpg
#   inflating: dataset/Validation/Z/89.jpg
#   inflating: dataset/Validation/Z/9.jpg
#   inflating: dataset/Validation/Z/90.jpg
#   inflating: dataset/Validation/Z/91.jpg
#   inflating: dataset/Validation/Z/92.jpg
#   inflating: dataset/Validation/Z/93.jpg
#   inflating: dataset/Validation/Z/94.jpg
#   inflating: dataset/Validation/Z/95.jpg
#   inflating: dataset/Validation/Z/96.jpg
#   inflating: dataset/Validation/Z/97.jpg
#   inflating: dataset/Validation/Z/98.jpg
#   inflating: dataset/Validation/Z/99.jpg

# %%
import os
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision
import torchvision.transforms as transforms
import torch.utils.data as data
import matplotlib.pyplot as plt
import tqdm
import IPython

# %%
train_directory = '../content/dataset/Train' 
val_directory = '../content/dataset/Validation'

# %%
def set_device():

  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("cpu!")
  else:
    print("GPU")

  return device
DEVICE = set_device()
# Out:
# GPU

# %%
# Prepare train and test dataloader
transform_image = transforms.Compose([
    transforms.Resize(32),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                         std=[0.5, 0.5, 0.5] )
    ])
Batch_size = 32
train_data = torchvision.datasets.ImageFolder(root=train_directory, transform=transform_image)
train_data_loader = data.DataLoader(train_data, batch_size=Batch_size, shuffle=True,  num_workers=0)
test_data = torchvision.datasets.ImageFolder(root=val_directory, transform=transform_image)
test_data_loader  = data.DataLoader(test_data, batch_size=Batch_size, shuffle=True, num_workers=0)

# %% [markdown]
# **transfer learning using resnet**

# %%
# Determine number of classes
# we have 39 kind of charrecters
num_classes = 39

# %%
from torchvision.models.resnet import resnet50
base = torchvision.models.resnet50(pretrained=True)
#  nuber of filters from the lasr layer of the pretrained model
num_filters = base.fc.in_features
# Reset final fully connected layer, number of classes = 39
base.fc = nn.Linear(num_filters, num_classes)
base.to(DEVICE)
# set optimizer
optimizer = torch.optim.NAdam(base.parameters(), lr=.0004)
# loss
lossfunc = nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
pretrained_accuracy = []
epochs = 40
for epoch in tqdm.tqdm(range(epochs)):
  
  nsamples = [] * 650000
  # Train loop
  for batch in train_data_loader:
    # spliting dataset 
    #if batch > nsamples:
    #  break
    if np.random.random() > 0.05:
      continue
    
    images, labels = batch
    images = images.to(DEVICE)
    labels = labels.to(DEVICE)

    optimizer.zero_grad()
    output = base(images)
    loss = lossfunc(output, labels)
    loss.backward()
    optimizer.step()

 # Eval loop
  with torch.no_grad():
    loss_sum = 0
    total_correct = 0
    total = len(test_data)
    for batch in test_data_loader:
      images, labels = batch
      images = images.to(DEVICE)
      labels = labels.to(DEVICE)
      output = base(images)
      loss = lossfunc(output, labels)
      loss_sum += loss.item()

      predictions = torch.argmax(output, dim=1)

      num_correct = torch.sum(predictions == labels)
      total_correct += num_correct 

    # Plot accuracy
    pretrained_accuracy.append(100 * total_correct.cpu() / total)
    plt.plot(pretrained_accuracy)
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Handwritten prediction accuracy')
    IPython.display.clear_output(wait=True)
    IPython.display.display(plt.gcf())
  plt.close()
# Out:
#  25%|██▌       | 10/40 [1:15:30<3:46:30, 453.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3f5272219396> in <module>()
#       5   nsamples = [] * 650000
#       6   # Train loop
# ----> 7   for batch in train_data_loader:
#       8     # spliting dataset
#       9     #if batch > nsamples:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     650                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     651                 self._reset()  # type: ignore[call-arg]
# --> 652             data = self._next_data()
#     653             self._num_yielded += 1
#     654             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     690     def _next_data(self):
#     691         index = self._next_index()  # may raise StopIteration
# --> 692         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     693         if self._pin_memory:
#     694             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     230         sample = self.loader(path)
#     231         if self.transform is not None:
# --> 232             sample = self.transform(sample)
#     233         if self.target_transform is not None:
#     234             target = self.target_transform(target)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      92     def __call__(self, img):
#      93         for t in self.transforms:
# ---> 94             img = t(img)
#      95         return img
#      96
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in forward(self, tensor)
#     267             Tensor: Normalized Tensor image.
#     268         """
# --> 269         return F.normalize(tensor, self.mean, self.std, self.inplace)
#     270
#     271     def __repr__(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py in normalize(tensor, mean, std, inplace)
#     358         raise TypeError(f"img should be Tensor Image. Got {type(tensor)}")
#     359
# --> 360     return F_t.normalize(tensor, mean=mean, std=std, inplace=inplace)
#     361
#     362
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional_tensor.py in normalize(tensor, mean, std, inplace)
#     957     if std.ndim == 1:
#     958         std = std.view(-1, 1, 1)
# --> 959     tensor.sub_(mean).div_(std)
#     960     return tensor
#     961
#
# KeyboardInterrupt:

# %%
print(pretrained_accuracy)
# Out:
# [tensor(93.3316), tensor(93.6512), tensor(93.1806), tensor(94.0819), tensor(94.2062), tensor(94.3083), tensor(92.1684), tensor(93.8244), tensor(92.7455), tensor(93.6201)]
